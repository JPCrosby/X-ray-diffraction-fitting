# %%
import pandas as pd
import matplotlib.pyplot as plt
from lmfit.models import GaussianModel, LorentzianModel
# Out:
# C:\Users\james\AppData\Local\Temp\ipykernel_31140\1474421775.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
GM1_813 = pd.read_csv('GM1-813/GM1-813/0DT2T(006)_Ex1.0_MONO_COL2.0_[29-34]_exported.xy', sep = ' ', header = 0)
GM1_813 = GM1_813.iloc[:, [0,1]]
GM1_813.columns = ['Angle', 'Intensity']

GM1_814 = pd.read_csv('GM1-814/GM1-814/0DT2T(006)_Ex1.0_MONO_COL2.0_[29-34]_exported.xy', sep = ' ', header = 0)
GM1_814 = GM1_814.iloc[:, [0,1]]
GM1_814.columns = ['Angle', 'Intensity']

GM1_815 = pd.read_csv('GM1-815/GM1-815/0DT2T(006)_Ex1.0_MONO_COL2.0_[29-34]_exported.xy', sep = ' ', header = 0)
GM1_815 = GM1_815.iloc[:, [0,1]]
GM1_815.columns = ['Angle', 'Intensity']

# %%
fig, ax = plt.subplots(figsize = (16, 9))
ax.plot(GM1_813['Angle'], GM1_813['Intensity'], label = 'GM1-813' )
ax.plot(GM1_814['Angle'], GM1_814['Intensity'] , label = 'GM1-814')
ax.plot(GM1_815['Angle'], GM1_815['Intensity'] , label = 'GM1-815')
ax.set_xlim(29, 34)
ax.grid()
ax.minorticks_on()
ax.legend()

# %%
GM1_805 = pd.read_csv('GM1-805/GM1-805/0DT2T_CuCrO2(006)_Ex1.0_mono_col2.0_AS0.6_MF_[29-34]_exported.xy', sep = ' ', header = 0, keep_default_na=False)
GM1_805 = GM1_805.iloc[:, [0,1]]
GM1_805.columns = ['Angle', 'Intensity']

GM1_804 = pd.read_csv('GM1-804/GM1-804/0DT2T_CuCrO2(006)_Ex1.0_mono_col2.0_AS0.6_MF_[29-34]_exported.xy', sep = ' ', header = 0, keep_default_na=False)
GM1_804 = GM1_804.iloc[:, [0,1]]
GM1_804.columns = ['Angle', 'Intensity']

GM1_803 = pd.read_csv('GM1-803/GM1-803/GM1-803_0DT2T_CuCrO2(006)_Ex1.0_mono_col2.0_AS0.6_MF_[29-34]_exported.xy', sep = ' ', header = 0, keep_default_na=False)
GM1_803 = GM1_803.iloc[:, [0,1]]
GM1_803.columns = ['Angle', 'Intensity']

# %%
(fig, (ax1)) = plt.subplots( figsize = (16, 9))
ax1.plot(GM1_803['Angle'], GM1_803['Intensity'] , label = 'GM1-803')
ax1.plot(GM1_804['Angle'], GM1_804['Intensity'], label ='GM1-804')
ax1.plot(GM1_805['Angle'], GM1_805['Intensity'] , label = 'GM1-805')
plt.legend()
ax1.grid()
ax1.minorticks_on()
ax1.set_xlim(29, 34)
# Out:
# (29.0, 34.0)

# %%
GM1_798 = pd.read_csv('GM1-798/GM1-798_2DT2T_Ex2_exported.xy', sep = ' ', header = 0, keep_default_na=False)
GM1_798 = GM1_798.iloc[:, [0,1]]
GM1_798.columns = ['Angle', 'Intensity']
